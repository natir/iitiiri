# %% [markdown]
# # Run benchmark

# %%
# !make -C experiment benchmark

# %% [markdown]
# # Create plot

# %%
import pandas
import pathlib

workdir = pathlib.Path("experiment")

def prepare_data(path: pathlib.Path, input_path: pathlib.Path):
    data = pandas.read_csv(path)

    data["input_size"] = input_path.stat().st_size

    data["error_min"] = data["mean"] - 2 * data["stddev"]
    data["error_max"] = data["mean"] + 2 * data["stddev"]

    return data

build = pandas.concat((
    prepare_data(workdir / "clinvar_build.csv", workdir / "clinvar.bed"),
    prepare_data(workdir / "gnomad_build.csv", workdir / "gnomad.bed"),
    prepare_data(workdir / "hg38_build.csv", workdir / "hg38.bed"),
    prepare_data(workdir / "combine_shuffle_build.csv", workdir / "combine_shuffle.bed"),
))

#query = pandas.concat((
#    prepare_data(workdir / "clinvar_query.csv", workdir / "clinvar.bed"),
#    prepare_data(workdir / "gnomad_query.csv", workdir / "gnomad.bed"),
#    prepare_data(workdir / "hg38_query.csv", workdir / "hg38.bed"),
#    prepare_data(workdir / "combine_shuffle_query.csv", workdir / "combine_shuffle.bed"),
#))

#query = query.merge(build, on=["command", "input_size"])
#query["mean"] = result["mean_x"] - result["mean_y"]
#query["error_min"] = query["error_min_x"]
#query["error_max"] = query["error_max_x"]

# %%
import altair

altair.renderers.set_embed_options(theme='dark')

def make_plot(data: pandas.DataFrame) -> altair.Chart:
    error = altair.Chart(data).mark_errorbar().encode(
        x=altair.X('input_size', title="input size(bytes)").scale(zero=False),
        y=altair.Y('error_min', title="wall time(s)"),
        y2=altair.Y2('error_max'),
        color=altair.Color('command'),
    )

    selection = altair.selection_point(fields=['command'])
    color = altair.condition(
        selection,
        altair.Color('command:N').legend(None),
        altair.value('lightgray')
    )
    opacity = altair.condition(selection, altair.value(1.0), altair.value(0.25))

    point = altair.Chart(data).mark_line().encode(
        x=altair.X("input_size", title="input size(bytes)"),
        y=altair.Y("mean", title="wall time(s)"),
        color=color,
        opacity=opacity,
    ).properties(
        width=800,
        height=800,
    )

    legend = altair.Chart(data).mark_point().encode(
        y=altair.Y('command:N').axis(orient='right'),
        color=color
    ).add_params(
        selection
    )

    return (point) | legend

make_plot(build).properties(
    title="Tree building",
)
